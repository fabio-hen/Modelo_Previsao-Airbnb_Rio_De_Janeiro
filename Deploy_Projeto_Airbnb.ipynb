# %%
import pandas as pd
import streamlit as st
import joblib

st.set_page_config(page_title="Previsão de Preço de Imóveis") # Define o título da página
st.title("Previsão de Preço de Imóveis Airbnb")
st.markdown("Utilize este formulário para estimar o preço de um imóvel com base em suas características.")

@st.cache_resource # Cache o modelo para que seja carregado apenas uma vez
def load_model():
    return joblib.load('modelo.joblib')

@st.cache_data # Cache o dataframe para que seja carregado apenas uma vez
def load_data():
    return pd.read_csv('dados.csv')

modelo = load_model()
dados = load_data()

# Dicionário com nomes mais amigáveis para exibição
labels = {
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'accommodates': 'Capacidade de hóspedes',
    'bathrooms': 'Número de banheiros',
    'bedrooms': 'Número de quartos',
    'beds': 'Número de camas',
    'extra_people': 'Pessoa extras adicional',
    'minimum_nights': 'Noites mínimas',
    'ano': 'Ano do anúncio',
    'mes': 'Mês do anúncio',
    'n_amenities': 'Quantidade de comodidades',
    'host_listings_count': 'Total de anúncios do anfitrião',
    'host_is_superhost': 'Anfitrião é Superhost?',
    'instant_bookable': 'Reserva instantânea?',
    'property_type': 'Tipo de propriedade',
    'room_type': 'Tipo de quarto',
    'cancellation_policy': 'Política de cancelamento'
}

# Dicionários originais
x_numericos = {'latitude': 0, 'longitude': 0, 'accommodates': 0, 'bathrooms': 0, 'bedrooms': 0, 'beds': 0, 'extra_people': 0,
               'minimum_nights': 0, 'ano': 0, 'mes': 0, 'n_amenities': 0, 'host_listings_count': 0}

x_tf = {'host_is_superhost': 0, 'instant_bookable': 0}

x_listas = {'property_type': ['Apartment', 'Bed and breakfast', 'Condominium', 'Guest suite', 'Guesthouse', 'Hostel', 'House', 'Loft', 'Outros', 'Serviced apartment'],
            'room_type': ['Entire home/apt', 'Hotel room', 'Private room', 'Shared room'],
            'cancellation_policy': ['flexible', 'moderate', 'strict', 'strict_14_with_grace_period']
            }


dicionario = {}

for item in x_listas:  #para cada chave do dicionario ele cria uma nova chave com _ e o valor
     for valor in x_listas[item]:
          dicionario[f'{item}_{valor}'] = 0



# Seção de entradas numéricas
st.header("Características numéricas do imóvel")
for item in x_numericos:
    # Usa .get() para segurança, caso a chave não esteja em labels
    display_label = labels.get(item, item.replace('_', ' ').title())
    if item == 'latitude' or item == 'longitude':
        valor = st.number_input(display_label, step=0.00001, value=0.0, format="%.5f")
    elif item == 'extra_people':
        valor = st.number_input(display_label, step=0.01, value=0.0)
    else:
        valor = st.number_input(display_label, step=1, value=0)
    x_numericos[item] = valor

# Seção de campos booleanos
st.header("Informações sobre reserva")
for item in x_tf:
    # Use labels.get(item, item) aqui
    display_label = labels.get(item, item)
    # Use display_label aqui
    valor = st.selectbox(display_label, ('Sim', 'Não'))
    if valor == 'Sim':
        x_tf[item] = 1
    else:
        x_tf[item] = 0

# Seção de categorias
st.header("Informações categóricas do anúncio")
for item in x_listas:
    # Use labels.get(item, item) aqui
    display_label = labels.get(item, item)
    # Use display_label aqui
    valor = st.selectbox(display_label, x_listas[item])
    dicionario[f'{item}_{valor}'] = 1

botao = st.button('Prever Valor do Imovél')

if botao:
     dicionario.update(x_numericos)
     dicionario.update(x_tf)
     valores_x = pd.DataFrame(dicionario, index=[0])
     dados = pd.read_csv('dados.csv') 
     colunas = list(dados.columns)[1:-1]
     valores_x = valores_x[colunas] #valor x vai ser o antigo valores de X mas na ordem colunas que foi obitido do dados.csv
     preco = modelo.predict(valores_x)
     st.success(f'O valor estimado do imóvel é: R$ {preco[0]:,.2f}')
# Out:
# 2025-06-04 20:13:13.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:13.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:13.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:13.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:13.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:13.484 No runtime found, using MemoryCacheStorageManager
# 2025-06-04 20:13:14.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 20:13:14.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
